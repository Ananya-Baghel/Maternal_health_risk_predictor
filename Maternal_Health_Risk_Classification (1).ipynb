# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Maternal Health Risk Data Set.csv')
data.head(10)
# Out:
#    Age  SystolicBP  DiastolicBP     BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.00      98.0         86  high risk
# 1   35         140           90  13.00      98.0         70  high risk
# 2   29          90           70   8.00     100.0         80  high risk
# 3   30         140           85   7.00      98.0         70  high risk
# 4   35         120           60   6.10      98.0         76   low risk
# 5   23         140           80   7.01      98.0         70  high risk
# 6   23         130           70   7.01      98.0         78   mid risk
# 7   35          85           60  11.00     102.0         86  high risk
# 8   32         120           90   6.90      98.0         70   mid risk
# 9   42         130           80  18.00      98.0         70  high risk

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1014 non-null   int64
#  1   SystolicBP   1014 non-null   int64
#  2   DiastolicBP  1014 non-null   int64
#  3   BS           1014 non-null   float64
#  4   BodyTemp     1014 non-null   float64
#  5   HeartRate    1014 non-null   int64
#  6   RiskLevel    1014 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 55.6+ KB

# %%
data.describe()
# Out:
#                Age   SystolicBP  DiastolicBP           BS     BodyTemp  \
# count  1014.000000  1014.000000  1014.000000  1014.000000  1014.000000
# mean     29.871795   113.198225    76.460552     8.725986    98.665089
# std      13.474386    18.403913    13.885796     3.293532     1.371384
# min      10.000000    70.000000    49.000000     6.000000    98.000000
# 25%      19.000000   100.000000    65.000000     6.900000    98.000000
# 50%      26.000000   120.000000    80.000000     7.500000    98.000000
# 75%      39.000000   120.000000    90.000000     8.000000    98.000000
# max      70.000000   160.000000   100.000000    19.000000   103.000000
#
#          HeartRate
# count  1014.000000
# mean     74.301775
# std       8.088702
# min       7.000000
# 25%      70.000000
# 50%      76.000000
# 75%      80.000000
# max      90.000000

# %% [markdown]
# # Checking the dataset distribution

# %%
data['RiskLevel'].unique()
# Out:
# array(['high risk', 'low risk', 'mid risk'], dtype=object)

# %%
data['RiskLevel'].value_counts()/len(data)
# Out:
# RiskLevel
# low risk     0.400394
# mid risk     0.331361
# high risk    0.268245
# Name: count, dtype: float64

# %%
data['RiskLevel'].value_counts().plot.pie(autopct='%.5f',figsize=(7,7))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Seperating dependent and independent variable

# %%
X=data.drop(columns=['RiskLevel'])
Y=data['RiskLevel']

# %%
X.shape
# Out:
# (1014, 6)

# %%
Y.shape
# Out:
# (1014,)

# %%
sns.pairplot(data,hue='RiskLevel')

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Age',hue='RiskLevel',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
correlation = data.drop(columns=['RiskLevel']).corr()
plt.figure(figsize=(12,8))
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot =True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='DiastolicBP',y='SystolicBP',hue='RiskLevel',data=data)
# Out:
# <Axes: xlabel='DiastolicBP', ylabel='SystolicBP'>

# %%
sns.scatterplot(x='RiskLevel',y='BS',hue='RiskLevel',data=data)
# Out:
# <Axes: xlabel='RiskLevel', ylabel='BS'>

# %%
sns.scatterplot(x='Age',y='BS',hue='RiskLevel',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='BS'>

# %%
sns.catplot(x="RiskLevel", y="SystolicBP", data=data, kind="box").set(title="Distribution based on SystolicBP")
sns.catplot(x="RiskLevel", y="DiastolicBP", data=data, kind="box").set(title="Distribution based on DiastolicBP")

# %% [markdown]
# # Scaling the dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

# %% [markdown]
# # Splitting the dataset

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(scaled_X,Y,train_size=0.70,stratify=Y,random_state=101)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((709, 6), (305, 6), (709,), (305,))

# %%
x_train.size
# Out:
# 4254

# %%
x_test.size
# Out:
# 1830

# %% [markdown]
# # Model Building, predictions and odds ratio

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression as LR
classifier=LR(class_weight='balanced')
classifier.fit(x_train,y_train)
predicted_values=classifier.predict(x_test)
predicted_probabilities=classifier.predict_proba(x_test)
predicted_values
predicted_probabilities,predicted_probabilities.shape
# Out:
# (array([[1.08770229e-01, 4.38092336e-01, 4.53137436e-01],
#         [3.67335631e-01, 2.25047331e-01, 4.07617038e-01],
#         [3.52013526e-02, 6.71761409e-01, 2.93037239e-01],
#         [1.24795004e-01, 2.69708945e-01, 6.05496051e-01],
#         [7.50977162e-02, 6.06852471e-01, 3.18049812e-01],
#         [1.70228400e-01, 1.89875424e-01, 6.39896176e-01],
#         [7.01495263e-02, 5.63918579e-01, 3.65931894e-01],
#         [3.54390712e-02, 4.16537002e-01, 5.48023927e-01],
#         [6.90734039e-01, 4.03307998e-02, 2.68935162e-01],
#         [5.64654497e-01, 7.21446224e-02, 3.63200880e-01],
#         [4.38362108e-01, 1.75989616e-01, 3.85648277e-01],
#         [3.43283948e-01, 2.00799982e-01, 4.55916070e-01],
#         [2.39028735e-02, 7.09876209e-01, 2.66220918e-01],
#         [9.66203872e-02, 4.26925721e-01, 4.76453892e-01],
#         [1.15178037e-01, 4.31269658e-01, 4.53552305e-01],
#         [1.90160540e-02, 7.66675626e-01, 2.14308320e-01],
#         [3.74714324e-02, 4.08489452e-01, 5.54039115e-01],
#         [9.49164566e-03, 8.01594129e-01, 1.88914226e-01],
#         [3.74714324e-02, 4.08489452e-01, 5.54039115e-01],
#         [2.97369048e-01, 3.11424178e-01, 3.91206774e-01],
#         [6.56314246e-01, 2.85805954e-02, 3.15105158e-01],
#         [9.86226242e-01, 8.45077740e-05, 1.36892498e-02],
#         [3.74714324e-02, 4.08489452e-01, 5.54039115e-01],
#         [8.23669441e-01, 1.91509781e-02, 1.57179581e-01],
#         [1.80288679e-01, 4.43440829e-01, 3.76270492e-01],
#         [1.20252559e-01, 5.32528865e-01, 3.47218576e-01],
#         [8.13954433e-02, 5.03932627e-01, 4.14671930e-01],
#         [5.64654497e-01, 7.21446224e-02, 3.63200880e-01],
#         [5.64654497e-01, 7.21446224e-02, 3.63200880e-01],
#         [2.19955354e-01, 3.94291760e-01, 3.85752886e-01],
#         [2.39028735e-02, 7.09876209e-01, 2.66220918e-01],
#         [2.09573213e-02, 7.46773571e-01, 2.32269107e-01],
#         [4.59466255e-02, 4.69873746e-01, 4.84179628e-01],
#         [9.30116040e-02, 4.72053357e-01, 4.34935039e-01],
#         [1.56146712e-02, 7.62896797e-01, 2.21488531e-01],
#         [1.07886499e-01, 4.06638045e-01, 4.85475456e-01],
#         [1.24795004e-01, 2.69708945e-01, 6.05496051e-01],
#         [7.61802533e-02, 4.63566326e-01, 4.60253421e-01],
#         [9.46947754e-01, 1.02466354e-03, 5.20275825e-02],
#         [6.95566617e-01, 6.01692047e-02, 2.44264178e-01],
#         [1.11884776e-02, 7.47919317e-01, 2.40892205e-01],
#         [3.92529181e-01, 2.06247857e-01, 4.01222963e-01],
#         [9.30380657e-01, 3.23737520e-03, 6.63819678e-02],
#         [4.97607557e-01, 1.40992755e-01, 3.61399688e-01],
#         [4.43070672e-01, 1.26291430e-01, 4.30637898e-01],
#         [1.77281282e-01, 1.83127248e-01, 6.39591470e-01],
#         [9.93676930e-01, 1.61271573e-05, 6.30694267e-03],
#         [7.61802533e-02, 4.63566326e-01, 4.60253421e-01],
#         [9.72057776e-03, 8.11714481e-01, 1.78564941e-01],
#         [1.56704672e-01, 2.03803670e-01, 6.39491658e-01],
#         [1.08532778e-01, 4.51227129e-01, 4.40240092e-01],
#         [1.76772619e-01, 4.45309829e-01, 3.77917552e-01],
#         [7.30480958e-01, 4.74664511e-02, 2.22052591e-01],
#         [1.69326913e-01, 3.93435950e-01, 4.37237137e-01],
#         [5.18510136e-01, 1.02112961e-01, 3.79376903e-01],
#         [1.91637992e-01, 4.24575154e-01, 3.83786854e-01],
#         [9.24822658e-02, 5.91086767e-01, 3.16430967e-01],
#         [6.29683087e-01, 5.38944869e-02, 3.16422426e-01],
#         [1.95729974e-01, 3.71511839e-01, 4.32758187e-01],
#         [5.59396983e-02, 5.68336950e-01, 3.75723352e-01],
#         [2.93840633e-02, 6.59450410e-01, 3.11165527e-01]]),
#  (305, 3))

# %%
y_train.shape
# Out:
# (709,)

# %%
predicted_values.shape
# Out:
# (305,)

# %%
y_test.shape
# Out:
# (305,)

# %% [markdown]
# 1. Confusion matrix(Logistic Regression)

# %%
from sklearn.metrics import confusion_matrix
cf=confusion_matrix(y_test,predicted_values)
cf
# Out:
# array([[60,  5, 17],
#        [ 6, 86, 30],
#        [23, 37, 41]])

# %% [markdown]
# 1(a)Accuracy matrix

# %%
classifier.score(x_test,y_test)
# Out:
# 0.6131147540983607

# %% [markdown]
# 1(b)Calculating the precision score

# %%
from sklearn.metrics import precision_recall_fscore_support as PRF_summary
precision,recall,f1,support=PRF_summary(y_test,predicted_values)

# %%
precision
# Out:
# array([0.6741573 , 0.671875  , 0.46590909])

# %%
recall
# Out:
# array([0.73170732, 0.70491803, 0.40594059])

# %%
f1
# Out:
# array([0.70175439, 0.688     , 0.43386243])

# %%
support
# Out:
# array([ 82, 122, 101])

# %%
sns.heatmap(confusion_matrix(y_test,predicted_values),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report
k=classification_report(y_test,predicted_values)
print(k)
# Out:
#               precision    recall  f1-score   support
#
#    high risk       0.67      0.73      0.70        82
#     low risk       0.67      0.70      0.69       122
#     mid risk       0.47      0.41      0.43       101
#
#     accuracy                           0.61       305
#    macro avg       0.60      0.61      0.61       305
# weighted avg       0.60      0.61      0.61       305

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred= model.predict(x_test)

# %%
sns.heatmap(confusion_matrix(y_test,pred),annot=True)
# Out:
# <Axes: >

# %%
model.score(x_test,y_test)
# Out:
# 0.8524590163934426

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#    high risk       0.86      0.94      0.90        82
#     low risk       0.89      0.83      0.86       122
#     mid risk       0.80      0.81      0.81       101
#
#     accuracy                           0.85       305
#    macro avg       0.85      0.86      0.85       305
# weighted avg       0.85      0.85      0.85       305

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x_train= scale.fit_transform(x_train)
x_test= scale.transform(x_test)

# %%
x_train
# Out:
# array([[-0.34096191,  0.34432827,  0.9405713 , -0.62741662,  1.73365201,
#          0.75085067],
#        [ 0.7672685 ,  2.58609821,  1.67573286,  3.08934025, -0.47759639,
#          0.38763498],
#        [-0.63649001, -1.33699918, -2.00007494, -0.56698155, -0.47759639,
#         -1.67058725],
#        ...,
#        [-0.93201812, -1.33699918, -1.04436491, -0.56698155,  1.73365201,
#         -0.45986829],
#        [-1.07978217, -2.12161866, -2.0735911 , -0.71806923, -0.47759639,
#          0.38763498],
#        [-0.63649001, -1.33699918, -0.8973326 , -0.38567634, -0.47759639,
#          0.26656309]])

# %%
modelDTC= DecisionTreeClassifier(criterion='gini', random_state=101)
modelDTC.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=101)

# %%
y_pred= modelDTC.predict(x_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_estimator(modelDTC,x_test,y_test)

# %%
modelDTC.score(x_test,y_test)
# Out:
# 0.8557377049180328

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    high risk       0.85      0.93      0.89        82
#     low risk       0.88      0.86      0.87       122
#     mid risk       0.82      0.79      0.81       101
#
#     accuracy                           0.86       305
#    macro avg       0.85      0.86      0.86       305
# weighted avg       0.86      0.86      0.86       305

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF= RandomForestClassifier(criterion='gini')
RF.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predict=RF.predict(x_test)

# %%
ConfusionMatrixDisplay.from_estimator(RF,x_test,y_test)

# %%
RF.score(x_test,y_test)
# Out:
# 0.8754098360655738

# %%
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#    high risk       0.87      0.93      0.90        82
#     low risk       0.89      0.89      0.89       122
#     mid risk       0.86      0.82      0.84       101
#
#     accuracy                           0.88       305
#    macro avg       0.87      0.88      0.88       305
# weighted avg       0.88      0.88      0.87       305

# %%
RF2= RandomForestClassifier(criterion='entropy',max_depth=30,max_features='sqrt',n_estimators=500)

# %%
RF2.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=30, n_estimators=500)

# %%
rf_pred=RF2.predict(x_test)

# %%
RF2.score(x_test,y_test)
# Out:
# 0.8721311475409836

# %%
print(classification_report(y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#    high risk       0.87      0.93      0.90        82
#     low risk       0.88      0.88      0.88       122
#     mid risk       0.86      0.82      0.84       101
#
#     accuracy                           0.87       305
#    macro avg       0.87      0.88      0.87       305
# weighted avg       0.87      0.87      0.87       305

# %%
ConfusionMatrixDisplay.from_estimator(RF2,x_test,y_test)

# %% [markdown]
# # Support Vector

# %%
from sklearn.svm import SVC

# %%
svc= SVC(kernel='poly')
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
svc_pred=svc.predict(x_test)

# %%
print(classification_report(y_test,svc_pred))
# Out:
#               precision    recall  f1-score   support
#
#    high risk       0.84      0.78      0.81        82
#     low risk       0.61      0.92      0.73       122
#     mid risk       0.66      0.29      0.40       101
#
#     accuracy                           0.67       305
#    macro avg       0.70      0.66      0.65       305
# weighted avg       0.69      0.67      0.64       305

# %%
svc.score(x_test,y_test)
# Out:
# 0.6721311475409836

# %%
ConfusionMatrixDisplay.from_estimator(svc,x_test,y_test)
